# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
data = pd.read_csv("../input/englandweather/EnglandWeather.csv")
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-01-01 00:00:00.000 +0100  Partly Cloudy        rain
# 1      2006-01-01 01:00:00.000 +0100  Mostly Cloudy        rain
# 2      2006-01-01 02:00:00.000 +0100  Mostly Cloudy        rain
# 3      2006-01-01 03:00:00.000 +0100       Overcast        rain
# 4      2006-01-01 04:00:00.000 +0100  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-12-31 19:00:00.000 +0100  Mostly Cloudy        rain
# 96449  2016-12-31 20:00:00.000 +0100  Mostly Cloudy        rain
# 96450  2016-12-31 21:00:00.000 +0100  Mostly Cloudy        snow
# 96451  2016-12-31 22:00:00.000 +0100  Mostly Cloudy        snow
# 96452  2016-12-31 23:00:00.000 +0100  Mostly Cloudy        snow
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             0.577778            17.1143               1016.66      0.89
# ...

# %%
df= pd.DataFrame(data)
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-01-01 00:00:00.000 +0100  Partly Cloudy        rain
# 1      2006-01-01 01:00:00.000 +0100  Mostly Cloudy        rain
# 2      2006-01-01 02:00:00.000 +0100  Mostly Cloudy        rain
# 3      2006-01-01 03:00:00.000 +0100       Overcast        rain
# 4      2006-01-01 04:00:00.000 +0100  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-12-31 19:00:00.000 +0100  Mostly Cloudy        rain
# 96449  2016-12-31 20:00:00.000 +0100  Mostly Cloudy        rain
# 96450  2016-12-31 21:00:00.000 +0100  Mostly Cloudy        snow
# 96451  2016-12-31 22:00:00.000 +0100  Mostly Cloudy        snow
# 96452  2016-12-31 23:00:00.000 +0100  Mostly Cloudy        snow
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             0.577778            17.1143               1016.66      0.89
# ...

# %%
print("\n missing value", data.isnull().sum())
# Out:
#  missing value Formatted Date            0
# Summary                   0
# Precip Type             517
# Temperature (C)           0
# Wind Speed (km/h)         0
# Pressure (millibars)      0
# Humidity                  0
# dtype: int64

# %%
df.describe()
# Out:
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count     96453.000000       96453.000000          96453.000000  96453.000000
# mean         11.932678          10.810640           1003.235956      0.734899
# std           9.551546           6.913571            116.969906      0.195473
# min         -21.822222           0.000000              0.000000      0.000000
# 25%           4.688889           5.828200           1011.900000      0.600000
# 50%          12.000000           9.965900           1016.450000      0.780000
# 75%          18.838889          14.135800           1021.090000      0.890000
# max          39.905556          63.852600           1046.380000      1.000000

# %%
df2= df.dropna()
df2
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-01-01 00:00:00.000 +0100  Partly Cloudy        rain
# 1      2006-01-01 01:00:00.000 +0100  Mostly Cloudy        rain
# 2      2006-01-01 02:00:00.000 +0100  Mostly Cloudy        rain
# 3      2006-01-01 03:00:00.000 +0100       Overcast        rain
# 4      2006-01-01 04:00:00.000 +0100  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-12-31 19:00:00.000 +0100  Mostly Cloudy        rain
# 96449  2016-12-31 20:00:00.000 +0100  Mostly Cloudy        rain
# 96450  2016-12-31 21:00:00.000 +0100  Mostly Cloudy        snow
# 96451  2016-12-31 22:00:00.000 +0100  Mostly Cloudy        snow
# 96452  2016-12-31 23:00:00.000 +0100  Mostly Cloudy        snow
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             0.577778            17.1143               1016.66      0.89
# ...

# %%
plt.figure(figsize=(10,8))
plt.bar(df2['Summary'],df2['Humidity'])
plt.xlabel("Weather Status" , size=15 , color='g')
plt.ylabel("Humidity", size=15 , color='g')
plt.xticks(rotation=90)
plt.title("UK Weather", size=15, color='r')
plt.grid()
plt.show()

# %%
new_date = df2["Formatted Date"].str.split(" ", n=2, expand = True)
new_date
# Out:
#                 0             1      2
# 0      2006-01-01  00:00:00.000  +0100
# 1      2006-01-01  01:00:00.000  +0100
# 2      2006-01-01  02:00:00.000  +0100
# 3      2006-01-01  03:00:00.000  +0100
# 4      2006-01-01  04:00:00.000  +0100
# ...           ...           ...    ...
# 96448  2016-12-31  19:00:00.000  +0100
# 96449  2016-12-31  20:00:00.000  +0100
# 96450  2016-12-31  21:00:00.000  +0100
# 96451  2016-12-31  22:00:00.000  +0100
# 96452  2016-12-31  23:00:00.000  +0100
#
# [95936 rows x 3 columns]

# %%
df3= df2.drop(columns=['Formatted Date'])
df3
# Out:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 0      Partly Cloudy        rain         0.577778            17.1143
# 1      Mostly Cloudy        rain         1.161111            16.6152
# 2      Mostly Cloudy        rain         1.666667            20.2538
# 3           Overcast        rain         1.711111            14.4900
# 4      Mostly Cloudy        rain         1.183333            13.9426
# ...              ...         ...              ...                ...
# 96448  Mostly Cloudy        rain         0.488889             9.7566
# 96449  Mostly Cloudy        rain         0.072222             9.4185
# 96450  Mostly Cloudy        snow        -0.233333             9.2736
# 96451  Mostly Cloudy        snow        -0.472222             9.2414
# 96452  Mostly Cloudy        snow        -0.677778             9.2253
#
#        Pressure (millibars)  Humidity
# 0                   1016.66      0.89
# 1                   1016.15      0.85
# ...

# %%
df3.insert(0,'date',new_date[0],True)
df3
# Out:
#              date        Summary Precip Type  Temperature (C)  \
# 0      2006-01-01  Partly Cloudy        rain         0.577778
# 1      2006-01-01  Mostly Cloudy        rain         1.161111
# 2      2006-01-01  Mostly Cloudy        rain         1.666667
# 3      2006-01-01       Overcast        rain         1.711111
# 4      2006-01-01  Mostly Cloudy        rain         1.183333
# ...           ...            ...         ...              ...
# 96448  2016-12-31  Mostly Cloudy        rain         0.488889
# 96449  2016-12-31  Mostly Cloudy        rain         0.072222
# 96450  2016-12-31  Mostly Cloudy        snow        -0.233333
# 96451  2016-12-31  Mostly Cloudy        snow        -0.472222
# 96452  2016-12-31  Mostly Cloudy        snow        -0.677778
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0                17.1143               1016.66      0.89
# 1                16.6152               1016.15      0.85
# ...

# %%
df4 = df3[::24]
df4
# Out:
#              date        Summary Precip Type  Temperature (C)  \
# 0      2006-01-01  Partly Cloudy        rain         0.577778
# 24     2006-01-02       Overcast        rain         5.422222
# 48     2006-01-03       Overcast        rain         1.694444
# 72     2006-01-04       Overcast        rain         2.200000
# 96     2006-01-05       Overcast        rain         1.666667
# ...           ...            ...         ...              ...
# 96349  2016-12-27  Mostly Cloudy        rain         2.338889
# 96373  2016-12-28  Mostly Cloudy        rain         2.283333
# 96397  2016-12-29  Mostly Cloudy        rain         2.222222
# 96421  2016-12-30  Mostly Cloudy        rain         2.172222
# 96445  2016-12-31  Mostly Cloudy        rain         2.122222
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0                17.1143               1016.66      0.89
# 24               13.6689               1009.60      0.86
# ...

# %%
df4.sort_values(by = "date")
df4
# Out:
#              date        Summary Precip Type  Temperature (C)  \
# 0      2006-01-01  Partly Cloudy        rain         0.577778
# 24     2006-01-02       Overcast        rain         5.422222
# 48     2006-01-03       Overcast        rain         1.694444
# 72     2006-01-04       Overcast        rain         2.200000
# 96     2006-01-05       Overcast        rain         1.666667
# ...           ...            ...         ...              ...
# 96349  2016-12-27  Mostly Cloudy        rain         2.338889
# 96373  2016-12-28  Mostly Cloudy        rain         2.283333
# 96397  2016-12-29  Mostly Cloudy        rain         2.222222
# 96421  2016-12-30  Mostly Cloudy        rain         2.172222
# 96445  2016-12-31  Mostly Cloudy        rain         2.122222
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0                17.1143               1016.66      0.89
# 24               13.6689               1009.60      0.86
# ...

# %%
Year= pd.to_datetime(df4.date).dt.year
Year
# Out:
# 0        2006
# 24       2006
# 48       2006
# 72       2006
# 96       2006
#          ...
# 96349    2016
# 96373    2016
# 96397    2016
# 96421    2016
# 96445    2016
# Name: date, Length: 3998, dtype: int64

# %%
df4.insert(loc=1 , column="Year", value = pd.to_datetime(df4['date']).dt.year)
df4
# Out:
#              date  Year        Summary Precip Type  Temperature (C)  \
# 0      2006-01-01  2006  Partly Cloudy        rain         0.577778
# 24     2006-01-02  2006       Overcast        rain         5.422222
# 48     2006-01-03  2006       Overcast        rain         1.694444
# 72     2006-01-04  2006       Overcast        rain         2.200000
# 96     2006-01-05  2006       Overcast        rain         1.666667
# ...           ...   ...            ...         ...              ...
# 96349  2016-12-27  2016  Mostly Cloudy        rain         2.338889
# 96373  2016-12-28  2016  Mostly Cloudy        rain         2.283333
# 96397  2016-12-29  2016  Mostly Cloudy        rain         2.222222
# 96421  2016-12-30  2016  Mostly Cloudy        rain         2.172222
# 96445  2016-12-31  2016  Mostly Cloudy        rain         2.122222
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0                17.1143               1016.66      0.89
# ...

# %%
df4.insert(loc=1 , column="month", value = pd.to_datetime(df4['date']).dt.month)
df4
# Out:
#              date  month  Year        Summary Precip Type  Temperature (C)  \
# 0      2006-01-01      1  2006  Partly Cloudy        rain         0.577778
# 24     2006-01-02      1  2006       Overcast        rain         5.422222
# 48     2006-01-03      1  2006       Overcast        rain         1.694444
# 72     2006-01-04      1  2006       Overcast        rain         2.200000
# 96     2006-01-05      1  2006       Overcast        rain         1.666667
# ...           ...    ...   ...            ...         ...              ...
# 96349  2016-12-27     12  2016  Mostly Cloudy        rain         2.338889
# 96373  2016-12-28     12  2016  Mostly Cloudy        rain         2.283333
# 96397  2016-12-29     12  2016  Mostly Cloudy        rain         2.222222
# 96421  2016-12-30     12  2016  Mostly Cloudy        rain         2.172222
# 96445  2016-12-31     12  2016  Mostly Cloudy        rain         2.122222
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# ...

# %%
Year= pd.to_datetime(df4.date).dt.year

# %%
plt.title("Number of row per Year")
sns.countplot(x=Year)
# Out:
# <AxesSubplot:title={'center':'Number of row per Year'}, xlabel='date', ylabel='count'>

# %%
Month= pd.to_datetime(df4.date).dt.month

# %%
plt.title("Number of row per Month")
sns.countplot(x=Month)
# Out:
# <AxesSubplot:title={'center':'Number of row per Month'}, xlabel='date', ylabel='count'>

# %%
Day= pd.to_datetime(df4.date).dt.day

# %%
plt.title("Number of row per Day")
sns.countplot(x=Day)
# Out:
# <AxesSubplot:title={'center':'Number of row per Day'}, xlabel='date', ylabel='count'>

# %%
df2["Formatted Date"]= pd.to_datetime(df2["Formatted Date"], utc=True)
yearlist= df2["Formatted Date"].dt.year.unique()
df2
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2005-12-31 23:00:00+00:00  Partly Cloudy        rain         0.577778
# 1     2006-01-01 00:00:00+00:00  Mostly Cloudy        rain         1.161111
# 2     2006-01-01 01:00:00+00:00  Mostly Cloudy        rain         1.666667
# 3     2006-01-01 02:00:00+00:00       Overcast        rain         1.711111
# 4     2006-01-01 03:00:00+00:00  Mostly Cloudy        rain         1.183333
# ...                         ...            ...         ...              ...
# ...

# %%
plt.figure(figsize=(10,8))
plt.scatter(df2['Temperature (C)'],df2['Humidity'])
plt.xlabel("Temperature" , size=15 , color='g')
plt.ylabel("Humidity", size=15 , color='g')
plt.xticks(rotation=90)
plt.title("UK Weather", size=15, color='r')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(df2['Wind Speed (km/h)'],df2['Humidity'])
plt.xlabel("Wind Speed (km/h)" , size=15 , color='g')
plt.ylabel("Humidity", size=15 , color='g')
plt.xticks(rotation=90)
plt.title("UK Weather", size=15, color='r')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(df2['Pressure (millibars)'],df2['Humidity'])
plt.xlabel("Pressure" , size=15 , color='g')
plt.ylabel("Humidity", size=15 , color='g')
plt.xticks(range(0,1000,100),rotation=90)
plt.title("UK Weather", size=15, color='r')
plt.grid()
plt.show()

# %%
for year in yearlist:
    df8 = df2[df2['Formatted Date'].dt.year == year].copy()
    df8['Month'] = df2.loc[:,'Formatted Date'].dt.month.astype(str)
    figure = plt.figure(figsize=(10 ,8))
    
    hue_order = ['snow','rain']
    countplot = sns.countplot(data=df8,x='Month',hue='Precip Type',hue_order=hue_order, palette='plasma')
    countplot.set_title('Month & Precip Type')
    plt.xlabel("Months of " + str(year))
    plt.savefig(f'D:\\MachinLearning\\ax\\{year}_PrecipType.png')
